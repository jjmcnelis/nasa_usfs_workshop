# %% [markdown]
# # SMV to xarray
#
# **read example SMV output to pandas df:**

# %%
import numpy as np
import pandas as pd
import xarray as xr
from io import StringIO

f = "docs/daily-smap-ORNL-DAAC-PccIuo.txt"          # example smv output
table = pd.read_csv(f, header=4, index_col="time")

datasets = list(table)
table.head(5)
# Out:
#            SoilSCAPE_surface SoilSCAPE_rootzone AirMOSS_L2_3_surface  \
# time
# 2012-09-20                ;;                 ;;                ;nan;
# 2012-09-21                ;;                 ;;                   ;;
# 2012-09-22                ;;                 ;;                   ;;
# 2012-09-23                ;;                 ;;                   ;;
# 2012-09-24                ;;                 ;;                   ;;
#
#            AirMOSS_L2_3_rootzone AirMOSS_L4_rootzone SMAP_surface  \
# time
# 2012-09-20                 ;7.2;       4.86;7.16;9.2           ;;
# 2012-09-21                    ;;       9.55;9.6;9.67           ;;
# 2012-09-22                    ;;      9.34;9.49;9.57           ;;
# 2012-09-23                    ;;      9.14;9.38;9.52           ;;
# 2012-09-24                    ;;      8.95;9.27;9.49           ;;
#
#            SMAP_rootzone NEE_mean GPP_mean prcp       ...        CRN_surface  \
# time                                                  ...
# 2012-09-20            ;;       ;;       ;;   ;;       ...                 ;;
# 2012-09-21            ;;       ;;       ;;   ;;       ...                 ;;
# 2012-09-22            ;;       ;;       ;;   ;;       ...                 ;;
# 2012-09-23            ;;       ;;       ;;   ;;       ...                 ;;
# 2012-09-24            ;;       ;;       ;;   ;;       ...                 ;;
#
#            CRN_rootzone SCAN_surface SCAN_rootzone SNOTEL_surface  \
# time
# 2012-09-20           ;;           ;;            ;;             ;;
# 2012-09-21           ;;           ;;            ;;             ;;
# 2012-09-22           ;;           ;;            ;;             ;;
# 2012-09-23           ;;           ;;            ;;             ;;
# 2012-09-24           ;;           ;;            ;;             ;;
#
#            SNOTEL_rootzone GRACE_surface_pctl GRACE_rootzone_pctl  \
# time
# 2012-09-20              ;;                 ;;                  ;;
# 2012-09-21              ;;                 ;;                  ;;
# 2012-09-22              ;;                 ;;                  ;;
# 2012-09-23              ;;                 ;;                  ;;
# 2012-09-24              ;;            ;19.59;             ;36.24;
#
#            FLUXNET_surface FLUXNET_rootzone
# time
# 2012-09-20              ;;               ;;
# 2012-09-21              ;;               ;;
# 2012-09-22              ;;               ;;
# 2012-09-23              ;;               ;;
# 2012-09-24              ;;               ;;
#
# [5 rows x 30 columns]

# %% [markdown]
# ## Products table
# #### https://daac.ornl.gov/soilmoisture/guide.html

# %%
smvds = pd.read_csv("docs/smvdatasets.csv", index_col="Column fieldname", header=0)
smvds
# Out:
#                                                                   Description  \
# Column fieldname
# SoilSCAPE_surface           Mean volumetric (%) soil moisture at 0-5 cm so...
# SoilSCAPE_rootzone          Mean volumetric (%) soil moisture at 0-100 cm ...
# AirMOSS_in-ground_surface   Mean volumetric (%) soil moisture at 0-5 cm so...
# AirMOSS_in-ground_rootzone  Mean volumetric (%) soil moisture at 0-100 cm ...
# COSMOS_surface              Mean volumetric (%) soil moisture at 0-5 cm so...
# COSMOS_rootzone             Mean volumetric (%) soil moisture at 0-100 cm ...
# AirMOSS_L2_3_surface        Mean volumetric (%) soil moisture at 0 cm soil...
# AirMOSS_L2_3_rootzone       Mean volumetric (%) soil moisture at 0-30cm so...
# AirMOSS_L4_rootzone         Mean volumetric (%) soil moisture at 0-100cm s...
# SMAP_surface                Mean volumetric (%) soil moisture at 0-5cm soi...
# SMAP_rootzone               Mean volumetric (%) soil moisture at 0-100cm s...
# NEE_mean                                    Mean Net Ecosystem Exchange value
# GPP_mean                                Mean Gross Primary Productivity value
# GRACE_surface_pctl                           Surface soil moisture percentile
# GRACE_rootzone_pctl                        Root zone soil moisture percentile
# SCAN_surface                Mean volumetric (%) soil moisture at 0-5cm soi...
# SCAN_rootzone               Mean volumetric (%) soil moisture at 0-40cm so...
# SNOTEL_surface              Mean volumetric (%) soil moisture at 0-5cm soi...
# SNOTEL_rootzone             Mean volumetric (%) soil moisture at 0-40cm so...
# CRN_surface                 Mean volumetric (%) soil moisture at 0-5cm soi...
# CRN_rootzone                Mean volumetric (%) soil moisture at 0-100cm s...
# FLUXNET_surface               Mean volumetric (%) soil moisture (upper layer)
# FLUXNET_rootzone            Mean volumetric (%) soil moisture (upper & low...
# prcp                              Precipitation for 1 km x 1 km grid (Daymet)
# tmax                        Maximum daily temperature for 1 km x 1 km grid...
# tmin                        Minimum daily temperature for 1 km x 1 km grid...
# ET                                                 Evapotranspiration (MODIS)
# LST_Day                                  Land Surface Temperature Day (MODIS)
# LST_Night                              Land Surface Temperature Night (MODIS)
# EVI                                 16 days Enhanced Vegetation Index (MODIS)
#
#                                  Units
# Column fieldname
# SoilSCAPE_surface                m3/m3
# SoilSCAPE_rootzone               m3/m3
# AirMOSS_in-ground_surface        m3/m3
# AirMOSS_in-ground_rootzone       m3/m3
# COSMOS_surface                   m3/m3
# COSMOS_rootzone                  m3/m3
# AirMOSS_L2_3_surface             m3/m3
# AirMOSS_L2_3_rootzone            m3/m3
# AirMOSS_L4_rootzone              m3/m3
# SMAP_surface                     m3/m3
# SMAP_rootzone                    m3/m3
# NEE_mean                    g C m-2d-1
# GPP_mean                    g C m-2d-1
# GRACE_surface_pctl                   %
# GRACE_rootzone_pctl                  %
# SCAN_surface                     m3/m3
# SCAN_rootzone                    m3/m3
# SNOTEL_surface                   m3/m3
# SNOTEL_rootzone                  m3/m3
# CRN_surface                      m3/m3
# CRN_rootzone                     m3/m3
# FLUXNET_surface                  m3/m3
# FLUXNET_rootzone                 m3/m3
# prcp                            mm/day
# tmax                         degrees C
# tmin                         degrees C
# ET                             mm/8day
# LST_Day                         K/8day
# LST_Night                       K/8day
# EVI                                NaN

# %% [markdown]
# **convert each pandas column into an `xarray.Dataset`:**

# %%
def getxr(series):

    # split columns into more columns; give names
    t = series.str.split(";", n = 2, expand=True)
    t.columns = ["Min", "Mean", "Max"]

    # replace empty strings w numpy.nan; all dtypes to float
    for col in t.columns:
        t[col].loc[t[col]==''] = np.nan
        t[col] = t[col].astype(float)
        
    # make an xarray.Dataset
    x = xr.Dataset(t)
    x.attrs = smvds.loc[series.name].to_dict()
    x.attrs["_FillValue"] = -9999.
    
    return(x)

# make dictionary of xr.Datasets; print one
xrds = {ds: getxr(table[ds]) for ds in datasets}
AirMOSS_L4_rootzone = xrds['AirMOSS_L4_rootzone']
AirMOSS_L4_rootzone['Mean'].plot

# %% [markdown]
# ## submit requests for the points selected on the map

# %%
requests.get("")
